# %%
import pickle
enron_data = pickle.load(open("final_project/final_project_dataset.pkl", "r"))

# %%
len(enron_data)
# Out:
# 146

# %%
len(enron_data.values()[0].keys())
# Out:
# 21

# %%
import pandas as pd

# %%
df_enron = pd.DataFrame(enron_data.values(),enron_data.keys())

# %%
df_enron.head()
# Out:
#                     bonus deferral_payments deferred_income director_fees  \
# METTS MARK         600000               NaN             NaN           NaN
# BAXTER JOHN C     1200000           1295738        -1386055           NaN
# ELLIOTT STEVEN     350000               NaN         -400729           NaN
# CORDES WILLIAM R      NaN               NaN             NaN           NaN
# HANNON KEVIN P    1500000               NaN        -3117011           NaN
#
#                              email_address exercised_stock_options expenses  \
# METTS MARK            mark.metts@enron.com                     NaN    94299
# BAXTER JOHN C                          NaN                 6680544    11200
# ELLIOTT STEVEN    steven.elliott@enron.com                 4890344    78552
# CORDES WILLIAM R     bill.cordes@enron.com                  651850      NaN
# HANNON KEVIN P      kevin.hannon@enron.com                 5538001    34039
#
#                  from_messages from_poi_to_this_person  \
# ...

# %%
df_enron[df_enron['poi']==True].sum()
# Out:
# poi    18
# dtype: int64

# %%
df_enron['Name'] = df_enron.index

# %%
df_enron.reset_index(level=0)
# Out:
#                     index    bonus deferral_payments deferred_income  \
# 0              METTS MARK   600000               NaN             NaN
# 1           BAXTER JOHN C  1200000           1295738        -1386055
# 2          ELLIOTT STEVEN   350000               NaN         -400729
# 3        CORDES WILLIAM R      NaN               NaN             NaN
# 4          HANNON KEVIN P  1500000               NaN        -3117011
# 5     MORDAUNT KRISTINA M   325000               NaN             NaN
# 6        MEYER ROCKFORD G      NaN           1848227             NaN
# 7         MCMAHON JEFFREY  2600000               NaN             NaN
# 8        HORTON STANLEY C      NaN           3131860             NaN
# 9         PIPER GREGORY F   400000           1130036          -33333
# 10        HUMPHREY GENE E      NaN           2964506             NaN
# 11         UMANOFF ADAM S   788750               NaN             NaN
# 12      BLACHMAN JEREMY M   850000               NaN             NaN
# ...

# %%
enron_data["PRENTICE JAMES"]["total_stock_value"]
# Out:
# 1095040

# %%
df_enron[df_enron['Name'] == "PRENTICE JAMES"].total_stock_value
# Out:
# PRENTICE JAMES    1095040
# Name: total_stock_value, dtype: object

# %% [markdown]
# 1. Cross validation: kfold, stratified kfold

# %% [markdown]
# 2. Gridsearch Cv for parameter tuning

# %%
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
svr = svm.SVC()
clf = grid_search.GridSearchCV(svr, parameters)
clf.fit(iris.data, iris.target)
